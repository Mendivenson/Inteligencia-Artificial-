# %% [markdown]
# # **Proyecto inteligencia artificial.**
#
# # **Detección de firmas falsas.**
#
# ### **Estadística. Facultad de Ciencias. Universidad Nacional de Colombia.**
#
# ### **Autores:**
#   - [Michel Mendivenson Barragán Zabala](mbarraganz@unal.edu.co)
#   - [Julieta Ruiz Castiblanco](druizca@unal.edu.co)
#   - [Nataly Astrid Quintero Ardila](nquinteroa@unal.edu.co)
#
#
#
# ---
#
#
# La detección de firmas falsas es un desafío crucial en el mundo actual, donde la autenticidad de documentos y transacciones legales es esencial. Los métodos manuales de verificación de firmas son propensos a errores y costosos en términos de tiempo y recursos. En respuesta a esta necesidad, se plantea este proyecto de aprendizaje profundo con el objetivo de desarrollar un sistema automático capaz de distinguir firmas auténticas de firmas falsificadas.
#
# Este proyecto se basa en el poder del aprendizaje profundo, una rama de la inteligencia artificial que ha demostrado su eficacia en una amplia gama de aplicaciones de visión por computadora. Aquí, aplicamos este enfoque para abordar un problema de seguridad crítico. A lo largo de esta demostración, exploraremos cómo entrenar un modelo de aprendizaje profundo para realizar esta tarea de detección de firmas falsas con una precisión excepcional.
#
# Nuestra motivación radica en la necesidad de mejorar la seguridad en documentos legales, prevenir fraudes y simplificar la verificación de firmas. A medida que avanzamos en esta demostración, demostraremos cómo el aprendizaje profundo puede ofrecer una solución eficaz para este desafío. Verás cómo entrenar un modelo de aprendizaje profundo para reconocer patrones y características en las firmas que escapan al ojo humano.
#
# El proceso involucra la adquisición y preparación de datos, la selección de un modelo adecuado, el entrenamiento del modelo y la evaluación de su desempeño. A través de ejemplos prácticos, demostraremos cómo se realiza cada uno de estos pasos. Además, discutiremos la importancia de los datos de validación para garantizar que el modelo pueda generalizar de manera efectiva y evitar el sobreajuste.
#
# ## **La base de datos:**
#
# La base de datos se encuentra alojada en la carpeta `sign_data` (Obtenida del siguiente [enlace](https://www.kaggle.com/datasets/robinreni/signature-verification-dataset) ) estructurada de la siguiente forma:

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# La siguiente línea cambiará en función de donde estén almacenados los datos, pero en este caso particular:
os.chdir('/content/drive/Shareddrives/2023-II/2023-II. Inteligencia Artificial (IA)/Proyecto IA') # Ruta Mendivenson
# os.chdir('/content/drive/My Drive/Proyecto IA') # Ruta Julieta
os.listdir('sign_data')
# Out:
# ['test_data.csv',
#  'train_data.csv',
#  'test',
#  'train',
#  'train_data',
#  'validation_data',
#  'test_data',
#  'signature_data']

# %% [markdown]
#   - En la carpeta se encuentran dos carpetas y dos archivos csv.
#     - La carpeta `train` corresponde a los datos de entrenamiento.
#     - La carpeta `test` corresponde a los datos de prueba (Aunque ya están metidos dentro de entrenamiento)
#     - El archivo `train_data.csv` y el archivo `test_data.csv` corresponde a archivos de identificadores para cada una de las carpetas (Nos dan información sobre si una imagen específica dentro de las carpetas de los datos de entrenamiento o test correpsonde a una firma falsa o genuina).
#
# Sin embargo, estos archivos `.csv` no los usaremos tanto debido a que las carpetas como tal tienen estructura que nos brinda esta información. Veamos:

# %%
sorted(os.listdir('sign_data/train'))[-10:-1]
# Out:
# ['065',
#  '065_forg',
#  '066',
#  '066_forg',
#  '067',
#  '067_forg',
#  '068',
#  '068_forg',
#  '069']

# %% [markdown]
# Dentro de cada una de las carpetas se encuentran más carpetas numeradas del uno al 69 siendo cada una de estas carpetas asignada para un individuo en específico y por cada individuo en específico hay dos sets de datos: `0##` conteniendo el set de firmas genuinas del individuo ## y `0**_forg` conteniendo el set de firmas falsas del individuo.

# %%
print(f'Hay {len(os.listdir("sign_data/train/001"))} firmas genuinas para cada individuo y {len(os.listdir("sign_data/train/001_forg"))} falsas.')
# Out:
# Hay 24 firmas genuinas para cada individuo y 8 falsas.

# %% [markdown]
# ## **Preprocesamiento de los datos:**
#
# Con el preprocesamiento queremos, en general alcanzar dos objetivos:
#
# - Convertir las imágenes a blanco y negro.
# - Dejar la misma altura y ancho para todas las imágenes.
# - Organizar los datos entre datos de entrenamiento, validación y datos de prueba.

# %%
import cv2
from tqdm import tqdm
from google.colab.patches import cv2_imshow
os.chdir('sign_data')

# %% [markdown]
#   ### **Convirtiendo las imágenes a blanco y negro:**
#
#   El módulo de python `cv2` nos brinda herramientas tanto para la visualización como para la manipulación de imágenes:

# %%
img = cv2.imread('train/001/001_01.PNG')
cv2_imshow(img)
# El siguiente comando nos da una tupla con la siguiente información del objeto img
img.shape
# (altura en píxeles, cncho en píxeles, canales de color de la imagen)
# Out:
# <PIL.Image.Image image mode=RGB size=725x359>
# (359, 725, 3)

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Note que en el siguiente comando
img_gray.shape
# Ya no aparecen argumento para los canales de color de la imagen.
# Es decir, hemos convertido la imagen a blanco y negro
# Out:
# <PIL.Image.Image image mode=L size=725x359>
# (359, 725)

# %% [markdown]
# ### **Mismo alto y ancho:**
#
# 1. Obtenemos el ancho y alto de todas las imágenes:

# %%
import pandas as pd
pd.options.mode.chained_assignment = None

height = []
width = []
for name in tqdm(os.listdir('train')):
    for image_name in os.listdir('train/'+name):
        img = cv2.imread('train/'+name+'/'+image_name)
        h, w, _ = img.shape
        height.append(h)
        width.append(w)
# Out:
# 100%|██████████| 128/128 [00:10<00:00, 12.09it/s]

# %% [markdown]
# Note que efctivamente las alturas y anchos de las imágenes en píxeles son distintos para cada imagen:

# %%
print(height[0:10])
print(width[0:10])
# Out:
# [379, 346, 240, 235, 308, 376, 346, 329, 231, 173]
# [723, 726, 911, 781, 826, 881, 814, 757, 791, 821]

# %% [markdown]
# 2. Definimos un ancho y alto estándar:

# %%
mean_height = int(sum(height)/len(height))
mean_width = int(sum(width)/len(width))
print(f'El ancho para todas las imágenes será {mean_width} y el alto {mean_height}')
# Out:
# El ancho para todas las imágenes será 650 y el alto 268

# %% [markdown]
# ### **Organizando las imágenes en blanco y negro del mismo tamaño en carpetas para la validación, el entrenamiento y los datos de prueba:**
#
# 1. Creamos las carpetas de entrenamiento, de prueba y de validación:

# %%
os.chdir('/content/drive/Shareddrives/2023-II/2023-II. Inteligencia Artificial (IA)/Proyecto IA/sign_data')
# os.chdir('/content/drive/My Drive/Proyecto IA/sign_data')
os.mkdir('../signature_data')
os.chdir('../signature_data')
os.mkdir('train_data')
os.mkdir('validation_data')
os.mkdir('test_data')

# %% [markdown]
# 2. Clasificación y transformación de las imágenes para darles la misma altura y ancho:
#
# **Nota:** La carpeta `signatura_data` va a estar estructurada de la misma forma que la carpeta `sign_data`: Cada carpeta dentro de las subcarpetas se corresponderá a un individuo en específico.

# %%
for name in tqdm(os.listdir('../sign_data/train')):
    num_images = len(os.listdir('../sign_data/train/'+name))
    i = 0
    os.mkdir('train_data/'+name)
    os.mkdir('validation_data/'+name)
    os.mkdir('test_data/'+name)
    for image_name in sorted(os.listdir('../sign_data/train/'+name)):
        img = cv2.imread('../sign_data/train/'+name+'/'+image_name)
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        img_resized = cv2.resize(img_gray, (mean_width, mean_height))
        if i < 7 * (num_images/10):
            cv2.imwrite('train_data/'+name+'/'+image_name, img_resized)
        elif i < 9 * (num_images/10):
            cv2.imwrite('validation_data/'+name+'/'+image_name, img_resized)
        else:
            cv2.imwrite('test_data/'+name+'/'+image_name, img_resized)
        i += 1
# Out:
# 100%|██████████| 128/128 [00:31<00:00,  4.10it/s]

# %% [markdown]
# Note que efectivamente las imágenes quedaron bien transformadas:

# %%
img = cv2.imread('train_data/001/001_01.PNG')
cv2_imshow(img)
img.shape
# Out:
# <PIL.Image.Image image mode=RGB size=650x268>
# (268, 650, 3)

# %% [markdown]
# ### **Lectura y almacenamiento de las imágenes:**

# %%
# Si se está trabajando en google collab se recomienda cambiar
# de CPU a T4 GPU en la sección 'Change runtime type' para que
# llegada la parte de entrenamiento del modelo el tiempo de
# ejecución sea menor.
import os
import cv2
from tqdm import tqdm
from google.colab.patches import cv2_imshow
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/Shareddrives/2023-II/2023-II. Inteligencia Artificial (IA)/Proyecto IA/signature_data')
#os.chdir('/content/drive/My Drive/Proyecto IA/sign_data')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np

def get_data(dir, labels = True):
    features = []
    targets = []
    for name in tqdm(sorted(os.listdir(dir))):
        for image_name in sorted(os.listdir(dir+'/'+name)):
            img = cv2.imread(dir+'/'+name+'/'+image_name)#, cv2.IMREAD_GRAYSCALE)
            features.append(img)
            if labels:
                if 'forg' in name.lower():
                    targets.append(1)
                else:
                    targets.append(0)
    if labels:
        return np.array(features),np.array(targets)
    else:
        return np.array(features)

# %%
train_features, train_labels = get_data('train_data', labels = True)
validation_features, validation_labels = get_data ('validation_data', labels = True)
test_features, test_labels = get_data('test_data', labels = True)
# Out:
# 100%|██████████| 128/128 [00:05<00:00, 21.77it/s]
# 100%|██████████| 128/128 [00:01<00:00, 96.79it/s]
# 100%|██████████| 128/128 [00:00<00:00, 227.33it/s]

# %%
print(train_features.shape)
print(validation_features.shape)
print(test_features.shape)
# Out:
# (1226, 268, 650, 3)
# (298, 268, 650, 3)
# (125, 268, 650, 3)

# %%
# Firmas reales
r = np.where(train_labels[0:(len(train_features[3]))] == 0)[0][1]
# Firmas falsas
f = np.where(train_labels[0:(len(train_features[3]))] == 1)[0][1]

# %%
cv2_imshow(train_features[r])
cv2_imshow(train_features[f])
del(r,f)
# Out:
# <PIL.Image.Image image mode=L size=650x268>
# <PIL.Image.Image image mode=L size=650x268>

# %%
train_features = train_features.reshape((1226, 268, 650, 3))
train_features = train_features.astype('float32') / 255
validation_features = validation_features.reshape((298, 268, 650, 3))
validation_features = validation_features.astype('float32') / 255
test_features = test_features.reshape((125, 268, 650, 3))
test_features = test_features.astype('float32') / 255

# %% [markdown]
# ## **CREACIÓN DE LOS MODELOS:**
#
# Con fines comparativos se generán varios modelos
#
# - Modelo básico de CNN
# - Inception-v3
# - VGG16
# - Oneshot learning

# %% [markdown]
# ---
#
# ### **RED NEURONAL CONVOLUCIONAL**

# %% [markdown]
# #### **Entrenamiento del modelo**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# train_features = np.expand_dims(train_features, axis=-1)
# validation_features = np.expand_dims(validation_features, axis=-1)
# test_features = np.expand_dims(test_features, axis=-1)

model = Sequential([
    # Convolutional layer with 32 filters, a kernel size of 3 and ReLU activation
    Conv2D(32, (3, 3), activation='relu', input_shape=(268, 650, 3)),
    MaxPooling2D((2, 2)),
    # Second convolutional layer with 64 filters
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    # Third convolutional layer with 128 filters
    Conv2D(128, (3, 3), activation='relu'),
    Flatten(),
    # Dense layer with 128 units
    Dense(128, activation='relu'),
    Dropout(0.5),
    # Output layer with single neuron, as we are doing binary classification
    Dense(1, activation='sigmoid')
])

# Compile the model with Adam optimizer and binary crossentropy loss
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
import time

start_time = time.time()
# Suponiendo que 'history' es el objeto devuelto por 'model.fit()'
history = model.fit(train_features, train_labels, epochs=15,
                    validation_data=(validation_features, validation_labels))
end_time = time.time()
# Out:
# Epoch 1/15
# 39/39 [==============================] - 26s 281ms/step - loss: 2.7941 - accuracy: 0.5163 - val_loss: 0.6616 - val_accuracy: 0.5570
# Epoch 2/15
# 39/39 [==============================] - 9s 226ms/step - loss: 0.3497 - accuracy: 0.8507 - val_loss: 0.7606 - val_accuracy: 0.8255
# Epoch 3/15
# 39/39 [==============================] - 8s 202ms/step - loss: 0.1787 - accuracy: 0.9462 - val_loss: 0.3684 - val_accuracy: 0.9027
# Epoch 4/15
# 39/39 [==============================] - 8s 215ms/step - loss: 0.0907 - accuracy: 0.9739 - val_loss: 0.4600 - val_accuracy: 0.8960
# Epoch 5/15
# 39/39 [==============================] - 8s 203ms/step - loss: 0.0482 - accuracy: 0.9829 - val_loss: 0.4214 - val_accuracy: 0.8926
# Epoch 6/15
# 39/39 [==============================] - 8s 217ms/step - loss: 0.0263 - accuracy: 0.9943 - val_loss: 0.5775 - val_accuracy: 0.8893
# Epoch 7/15
# 39/39 [==============================] - 8s 203ms/step - loss: 0.0329 - accuracy: 0.9878 - val_loss: 0.7711 - val_accuracy: 0.8960
# Epoch 8/15
# 39/39 [==============================] - 9s 232ms/step - loss: 0.0107 - accuracy: 0.9951 - val_loss: 0.7824 - val_accuracy: 0.8960
# Epoch 9/15
# 39/39 [==============================] - 8s 205ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.8242 - val_accuracy: 0.8993
# Epoch 10/15
# 39/39 [==============================] - 8s 217ms/step - loss: 0.0420 - accuracy: 0.9886 - val_loss: 0.7600 - val_accuracy: 0.8993
# Epoch 11/15
# 39/39 [==============================] - 8s 203ms/step - loss: 0.0095 - accuracy: 0.9976 - val_loss: 1.3125 - val_accuracy: 0.8893
# Epoch 12/15
# 39/39 [==============================] - 9s 219ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 1.0348 - val_accuracy: 0.9027
# Epoch 13/15
# 39/39 [==============================] - 8s 203ms/step - loss: 0.3401 - accuracy: 0.9086 - val_loss: 0.5345 - val_accuracy: 0.8826
# Epoch 14/15
# 39/39 [==============================] - 8s 218ms/step - loss: 0.1797 - accuracy: 0.9592 - val_loss: 0.7381 - val_accuracy: 0.8826
# Epoch 15/15
# 39/39 [==============================] - 8s 204ms/step - loss: 0.0376 - accuracy: 0.9910 - val_loss: 1.0124 - val_accuracy: 0.8859

# %% [markdown]
# #### **Resultados**
#
# ##### **Modelo:**

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 266, 648, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 133, 324, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 131, 322, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 65, 161, 64)       0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 63, 159, 128)      73856
#
#  flatten (Flatten)           (None, 1282176)           0
#
#  dense (Dense)               (None, 128)               164118656
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 164212033 (626.42 MB)
# Trainable params: 164212033 (626.42 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(f'El modelo tardo {(end_time - start_time)/60} minutos en entrenarse.')
# Out:
# El modelo tardo 2.479522220293681 minutos en entrenarse.

# %% [markdown]
# ##### **Precisión y pérdida**

# %%
from matplotlib import pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import pandas as pd
from IPython.display import HTML

# Valores finales:
resultados = np.array([[history.history['accuracy'][-1], history.history['loss'][-1]],
                       [history.history['val_accuracy'][-1], history.history['val_loss'][-1]]])

df = pd.DataFrame(resultados, index = ['Entrenamiento','Validación'],
                  columns = ['Precisión','Pérdida'])

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Precisión</th>
#       <th>Pérdida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Entrenamiento</th>
#       <td>0.991028</td>
#       <td>0.037650</td>
#     </tr>
#     <tr>
#       <th>Validación</th>
#       <td>0.885906</td>
#       <td>1.012448</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Comprobando la precisión con los datos de prueba**

# %%
a = %who_ls
borrar = list(filter(lambda x: 'test' in x, a))
borrar += list(filter(lambda x: 'test' in x, a))
a = list(filter(lambda x: x not in borrar, a))
a.remove('model')
a.remove('resultados')
for i in a:
  del globals()[i]
del a
del borrar
del i
# %who_ls
# Out:
# ['model', 'resultados', 'test_features', 'test_labels']

# %%
# Evaluate the model with the test data
test_loss, test_acc = model.evaluate(test_features, test_labels)
print(f'Los resultados de la evaluación con los datos de prueba fueron:\n'
      f'- Precisión: {test_acc:.4f}\n- Pérdida: {test_loss:.4f}')
# Out:
# 4/4 [==============================] - 1s 362ms/step - loss: 0.7342 - accuracy: 0.8880
# Los resultados de la evaluación con los datos de prueba fueron:
# - Precisión: 0.8880
# - Pérdida: 0.7342

# %%
import numpy as np
import pandas as pd
from IPython.display import HTML
# Precisión: Tasa de clasifiación correcta.
# Pérdida  : Cuán cerca está la salida del modelo de las etiquetas reales.
resultados = np.vstack((resultados, [test_acc,test_loss]))
df = pd.DataFrame(resultados, index = ['Entrenamiento','Validación','Test'],
                  columns = ['Precisión','Pérdida'])
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Precisión</th>
#       <th>Pérdida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Entrenamiento</th>
#       <td>0.991028</td>
#       <td>0.037650</td>
#     </tr>
#     <tr>
#       <th>Validación</th>
#       <td>0.885906</td>
#       <td>1.012448</td>
#     </tr>
#     <tr>
#       <th>Test</th>
#       <td>0.888000</td>
#       <td>0.734243</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Guardando el modelo**

# %% [markdown]
# ---
#
# ### **VGG16**
#
# VGG16, que significa "Visual Geometry Group 16," es una arquitectura de red neuronal convolucional (CNN) diseñada por el grupo de investigación Visual Geometry Group de la Universidad de Oxford. VGG16 es una de las arquitecturas de CNN más influyentes y ampliamente utilizadas en la comunidad de aprendizaje profundo, y se ha convertido en un punto de referencia para tareas de clasificación de imágenes.

# %%
# Importando el modelo
from keras.applications import VGG16

# El modelo usará los pesos pre entrenados con la base de datos de imagenet
# con inputs de 268 * 650 y 3 canales de color
conv_base = VGG16(weights='imagenet', include_top=False, input_shape=(268, 650, 3))

# TRANSFER LEARNING:
# El modelo no se volverá a entrenar: Los pesos del modelo entrenados con imagenet
# se mantendrán
for k,v in  conv_base._get_trainable_state().items():
    k.trainable = False

# Extraer los pesos preentrenados:
# model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
# weights = model.get_weights()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
from keras import layers
from keras import models
from keras import optimizers

# Se crea un modelo secuencial:
end_model = models.Sequential()

# Se agrega a este último modelo una capa de aplanamiento: La salida de
# VGG16 se transforma en un vector unidimensional.
end_model.add(layers.Flatten(input_shape=conv_base.output_shape[1:]))

# Capas de aprendizaje intermedio
end_model.add(layers.Dense(64, activation='relu'))
end_model.add(layers.Dense(64, activation='relu'))

# Esta última capa es una capa densamente conectada con una unidad. En últimas esta
# capa nos dirá si la firma dada es falsa o verdadera.
end_model.add(layers.Dense(1, activation='sigmoid'))

# Combinamos el modelo VGG16 (En este caso llamado `conv_base`) y el modelo
# secuencial end_model
model = models.Model(inputs=conv_base.input, outputs=end_model(conv_base.output))

# Se compila el modelo con un optimizador RMsprop (Con una taza de aprendizaje de 10^-6) y
# la función de pérdida `binary_crossentropy` (Apropiada para problemas de clasificación)
# binarios.
model.compile(optimizer=optimizers.RMSprop(learning_rate=1e-6),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# #### **Entrenamiento del modelo**

# %%
import time
# El modelo VGG16 + red secuencial se entrena acá¿ usando los datos de entrenamiento
# como entrenamiento (Recuerde que 0 es una firma genuina y uno una firma falsa):
# + epochs          : Iteraciones completas a tráves de todo el conjunto de datos.
# + batch_size      : Cuántas muestras por vez se usarán para el entrenamiento.
# + validation_data : Los datos de la validación del rendimiento del modelo.

start_time = time.time()
history = model.fit(train_features, train_labels,
                    epochs=100, batch_size=32,
                    validation_data=(validation_features, validation_labels))
end_time = time.time()
# Out:
# Epoch 1/100
# 39/39 [==============================] - 45s 697ms/step - loss: 0.6907 - accuracy: 0.5489 - val_loss: 0.6884 - val_accuracy: 0.5268
# Epoch 2/100
# 39/39 [==============================] - 22s 563ms/step - loss: 0.6740 - accuracy: 0.5767 - val_loss: 0.6761 - val_accuracy: 0.6040
# Epoch 3/100
# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 268, 650, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 268, 650, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 268, 650, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 134, 325, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 134, 325, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 134, 325, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 67, 162, 128)      0
#
#  block3_conv1 (Conv2D)       (None, 67, 162, 256)      295168
#
#  block3_conv2 (Conv2D)       (None, 67, 162, 256)      590080
#
#  block3_conv3 (Conv2D)       (None, 67, 162, 256)      590080
#
#  block3_pool (MaxPooling2D)  (None, 33, 81, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 33, 81, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 33, 81, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 33, 81, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 40, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 40, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 40, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 40, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 20, 512)        0
#
#  sequential (Sequential)     (None, 1)                 5247169
#
# =================================================================
# Total params: 19961857 (76.15 MB)
# Trainable params: 5247169 (20.02 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
print(f'El modelo tardó {(end_time - start_time)/60} minutos en entrenarse.')
# Out:
# El modelo tardó 37.504297987620035 minutos en entrenarse.

# %% [markdown]
# ##### **Precisión y pérdida**

# %%
from matplotlib import pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import pandas as pd
from IPython.display import HTML

# Valores finales:
resultados = np.array([[history.history['accuracy'][-1], history.history['loss'][-1]],
                       [history.history['val_accuracy'][-1], history.history['val_loss'][-1]]])

df = pd.DataFrame(resultados, index = ['Entrenamiento','Validación'],
                  columns = ['Precisión','Pérdida'])

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Precisión</th>
#       <th>Pérdida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Entrenamiento</th>
#       <td>0.994290</td>
#       <td>0.107672</td>
#     </tr>
#     <tr>
#       <th>Validación</th>
#       <td>0.966443</td>
#       <td>0.181647</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Comprobando la precisión con los datos de prueba**

# %%
# Al agregar más datos a los datos de validación y entrenamiento el modelo es más
# pesado y consume más memoria RAM por ende Collab puede llegar a fallar al hacer
# el test en la siguiente celda. Por eso existe esta línea.
# Para liberar memoria y que no se quedé sin espacio en RAM
a = %who_ls
a.remove('model')
a.remove('test_features')
a.remove('test_labels')
a.remove('resultados')
for i in a:
  del globals()[i]
del i
# %who_ls
# Out:
# ['a', 'model', 'resultados', 'test_features', 'test_labels']

# %%
test_loss, test_acc = model.evaluate(test_features, test_labels)
# Out:
# 4/4 [==============================] - 10s 3s/step - loss: 0.2210 - accuracy: 0.9440

# %%
import numpy as np
import pandas as pd
from IPython.display import HTML

# Precisión: Tasa de clasificación correcta.
# Pérdida  : Cuán cerca está la salida del modelo de las etiquetas reales.
resultados = np.vstack((resultados, [test_acc,test_loss]))
df = pd.DataFrame(resultados, index = ['Entrenamiento','Validación','Test'],
                  columns = ['Precisión','Pérdida'])
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Precisión</th>
#       <th>Pérdida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Entrenamiento</th>
#       <td>0.994290</td>
#       <td>0.107672</td>
#     </tr>
#     <tr>
#       <th>Validación</th>
#       <td>0.966443</td>
#       <td>0.181647</td>
#     </tr>
#     <tr>
#       <th>Test</th>
#       <td>0.944000</td>
#       <td>0.220988</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Guardando el modelo**

# %%
import os
os.chdir('..')
model.save('vgg16.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ---
#
# ### **INCEPTION-V3**

# %% [markdown]
# Inception-v3 es una arquitectura de red neuronal convolucional (CNN) diseñada para tareas de visión por computadora, específicamente para clasificación de imágenes. Su capacidad para capturar información a múltiples escalas mediante módulos de convolución hace que sea especialmente útil para la detección de características complejas en imágenes.

# %%
from keras.applications import InceptionV3
from keras import layers
from keras import models
from keras import optimizers

# Importar el modelo Inception-v3 con pesos preentrenados en ImageNet
conv_base_inception = InceptionV3(weights='imagenet', include_top=False, input_shape=(268, 650, 3))

# Transfer Learning: Congelar los pesos del modelo preentrenado
for layer in conv_base_inception.layers:
    layer.trainable = False

# Crear el modelo secuencial para agregar capas personalizadas
end_model_inception = models.Sequential()

# Añadir una capa de aplanamiento a la salida de Inception-v3
end_model_inception.add(layers.Flatten(input_shape=conv_base_inception.output_shape[1:]))

# Añadir capas de aprendizaje intermedio
end_model_inception.add(layers.Dense(64, activation='relu'))
end_model_inception.add(layers.Dense(64, activation='relu'))

# Añadir una capa densa final con una unidad de salida (problema de clasificación binaria)
end_model_inception.add(layers.Dense(1, activation='sigmoid'))

# Combinar el modelo Inception-v3 con el modelo secuencial personalizado
model_inception = models.Model(inputs=conv_base_inception.input, outputs=end_model_inception(conv_base_inception.output))

# Compilar el modelo con el optimizador RMSprop y la función de pérdida binary_crossentropy
model_inception.compile(optimizer=optimizers.RMSprop(learning_rate=1e-6), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# #### **Entrenar el modelo**

# %%
import time

start_time = time.time()
# Entrenar el modelo con los datos de entrenamiento y validación
history_inception = model_inception.fit(train_features, train_labels,
                                        epochs=15, batch_size=32,
                                        validation_data=(validation_features, validation_labels))
end_time = time.time()
# Out:
# Epoch 1/15
# 39/39 [==============================] - 30s 432ms/step - loss: 0.6468 - accuracy: 0.6191 - val_loss: 0.6222 - val_accuracy: 0.6544
# Epoch 2/15
# 39/39 [==============================] - 12s 299ms/step - loss: 0.5253 - accuracy: 0.7838 - val_loss: 0.5360 - val_accuracy: 0.7483
# Epoch 3/15
# 39/39 [==============================] - 11s 294ms/step - loss: 0.4267 - accuracy: 0.8589 - val_loss: 0.4706 - val_accuracy: 0.7819
# Epoch 4/15
# 39/39 [==============================] - 11s 279ms/step - loss: 0.3493 - accuracy: 0.9021 - val_loss: 0.4300 - val_accuracy: 0.8087
# Epoch 5/15
# 39/39 [==============================] - 12s 301ms/step - loss: 0.2867 - accuracy: 0.9331 - val_loss: 0.3940 - val_accuracy: 0.8423
# Epoch 6/15
# 39/39 [==============================] - 11s 294ms/step - loss: 0.2357 - accuracy: 0.9494 - val_loss: 0.3739 - val_accuracy: 0.8456
# Epoch 7/15
# 39/39 [==============================] - 11s 285ms/step - loss: 0.1962 - accuracy: 0.9641 - val_loss: 0.3281 - val_accuracy: 0.8826
# Epoch 8/15
# 39/39 [==============================] - 12s 303ms/step - loss: 0.1632 - accuracy: 0.9747 - val_loss: 0.3184 - val_accuracy: 0.8792
# Epoch 9/15
# 39/39 [==============================] - 12s 300ms/step - loss: 0.1346 - accuracy: 0.9861 - val_loss: 0.2802 - val_accuracy: 0.8926
# Epoch 10/15
# 39/39 [==============================] - 11s 294ms/step - loss: 0.1118 - accuracy: 0.9902 - val_loss: 0.2907 - val_accuracy: 0.8893
# Epoch 11/15
# 39/39 [==============================] - 11s 292ms/step - loss: 0.0935 - accuracy: 0.9943 - val_loss: 0.3416 - val_accuracy: 0.8557
# Epoch 12/15
# 39/39 [==============================] - 12s 308ms/step - loss: 0.0808 - accuracy: 0.9959 - val_loss: 0.2410 - val_accuracy: 0.9060
# Epoch 13/15
# 39/39 [==============================] - 12s 299ms/step - loss: 0.0668 - accuracy: 0.9992 - val_loss: 0.2930 - val_accuracy: 0.8826
# Epoch 14/15
# 39/39 [==============================] - 12s 298ms/step - loss: 0.0561 - accuracy: 0.9992 - val_loss: 0.2191 - val_accuracy: 0.9262
# Epoch 15/15
# 39/39 [==============================] - 12s 304ms/step - loss: 0.0476 - accuracy: 1.0000 - val_loss: 0.2195 - val_accuracy: 0.9128

# %% [markdown]
# #### **Resultados**
#
# ##### **Modelo:**

# %%
model_inception.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 268, 650, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 133, 324, 32)         864       ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 133, 324, 32)         96        ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 133, 324, 32)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 131, 322, 32)         9216      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 131, 322, 32)         96        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 131, 322, 32)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 131, 322, 64)         18432     ['activation_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 131, 322, 64)         192       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 131, 322, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 65, 160, 64)          0         ['activation_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 65, 160, 80)          5120      ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (Bat  (None, 65, 160, 80)          240       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 65, 160, 80)          0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 63, 158, 192)         138240    ['activation_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 63, 158, 192)         576       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 63, 158, 192)         0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 31, 78, 192)          0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_8 (Conv2D)           (None, 31, 78, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 31, 78, 64)           192       ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 31, 78, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 31, 78, 48)           9216      ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 31, 78, 96)           55296     ['activation_8[0][0]']
#
#  batch_normalization_6 (Bat  (None, 31, 78, 48)           144       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 31, 78, 96)           288       ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 31, 78, 48)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  activation_9 (Activation)   (None, 31, 78, 96)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  average_pooling2d (Average  (None, 31, 78, 192)          0         ['max_pooling2d_1[0][0]']
#  Pooling2D)
#
#  conv2d_5 (Conv2D)           (None, 31, 78, 64)           12288     ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 31, 78, 64)           76800     ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 31, 78, 96)           82944     ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 31, 78, 32)           6144      ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (Bat  (None, 31, 78, 64)           192       ['conv2d_5[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 31, 78, 64)           192       ['conv2d_7[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 31, 78, 96)           288       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 31, 78, 32)           96        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 31, 78, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  activation_7 (Activation)   (None, 31, 78, 64)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 31, 78, 96)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 31, 78, 32)           0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  mixed0 (Concatenate)        (None, 31, 78, 256)          0         ['activation_5[0][0]',
#                                                                      'activation_7[0][0]',
#                                                                      'activation_10[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 31, 78, 64)           16384     ['mixed0[0][0]']
#
#  batch_normalization_15 (Ba  (None, 31, 78, 64)           192       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 31, 78, 48)           12288     ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 31, 78, 96)           55296     ['activation_15[0][0]']
#
#  batch_normalization_13 (Ba  (None, 31, 78, 48)           144       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  batch_normalization_16 (Ba  (None, 31, 78, 96)           288       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 31, 78, 48)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  activation_16 (Activation)  (None, 31, 78, 96)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  average_pooling2d_1 (Avera  (None, 31, 78, 256)          0         ['mixed0[0][0]']
#  gePooling2D)
#
#  conv2d_12 (Conv2D)          (None, 31, 78, 64)           16384     ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 31, 78, 64)           76800     ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 31, 78, 96)           82944     ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 31, 78, 64)           16384     ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (Ba  (None, 31, 78, 64)           192       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 31, 78, 64)           192       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 31, 78, 96)           288       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  batch_normalization_18 (Ba  (None, 31, 78, 64)           192       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  activation_14 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  activation_17 (Activation)  (None, 31, 78, 96)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  activation_18 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  mixed1 (Concatenate)        (None, 31, 78, 288)          0         ['activation_12[0][0]',
#                                                                      'activation_14[0][0]',
#                                                                      'activation_17[0][0]',
#                                                                      'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 31, 78, 64)           18432     ['mixed1[0][0]']
#
#  batch_normalization_22 (Ba  (None, 31, 78, 64)           192       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 31, 78, 48)           13824     ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 31, 78, 96)           55296     ['activation_22[0][0]']
#
#  batch_normalization_20 (Ba  (None, 31, 78, 48)           144       ['conv2d_20[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 31, 78, 96)           288       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 31, 78, 48)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  activation_23 (Activation)  (None, 31, 78, 96)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  average_pooling2d_2 (Avera  (None, 31, 78, 288)          0         ['mixed1[0][0]']
#  gePooling2D)
#
#  conv2d_19 (Conv2D)          (None, 31, 78, 64)           18432     ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 31, 78, 64)           76800     ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 31, 78, 96)           82944     ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 31, 78, 64)           18432     ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (Ba  (None, 31, 78, 64)           192       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 31, 78, 64)           192       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 31, 78, 96)           288       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 31, 78, 64)           192       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  activation_21 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  activation_24 (Activation)  (None, 31, 78, 96)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  activation_25 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  mixed2 (Concatenate)        (None, 31, 78, 288)          0         ['activation_19[0][0]',
#                                                                      'activation_21[0][0]',
#                                                                      'activation_24[0][0]',
#                                                                      'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 31, 78, 64)           18432     ['mixed2[0][0]']
#
#  batch_normalization_27 (Ba  (None, 31, 78, 64)           192       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 31, 78, 64)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 31, 78, 96)           55296     ['activation_27[0][0]']
#
#  batch_normalization_28 (Ba  (None, 31, 78, 96)           288       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 31, 78, 96)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 15, 38, 384)          995328    ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 15, 38, 96)           82944     ['activation_28[0][0]']
#
#  batch_normalization_26 (Ba  (None, 15, 38, 384)          1152      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 15, 38, 96)           288       ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 15, 38, 384)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  activation_29 (Activation)  (None, 15, 38, 96)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 15, 38, 288)          0         ['mixed2[0][0]']
#  g2D)
#
#  mixed3 (Concatenate)        (None, 15, 38, 768)          0         ['activation_26[0][0]',
#                                                                      'activation_29[0][0]',
#                                                                      'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 15, 38, 128)          98304     ['mixed3[0][0]']
#
#  batch_normalization_34 (Ba  (None, 15, 38, 128)          384       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 15, 38, 128)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 15, 38, 128)          114688    ['activation_34[0][0]']
#
#  batch_normalization_35 (Ba  (None, 15, 38, 128)          384       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 15, 38, 128)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 15, 38, 128)          98304     ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 15, 38, 128)          114688    ['activation_35[0][0]']
#
#  batch_normalization_31 (Ba  (None, 15, 38, 128)          384       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 15, 38, 128)          384       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 15, 38, 128)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  activation_36 (Activation)  (None, 15, 38, 128)          0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 15, 38, 128)          114688    ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 15, 38, 128)          114688    ['activation_36[0][0]']
#
#  batch_normalization_32 (Ba  (None, 15, 38, 128)          384       ['conv2d_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 15, 38, 128)          384       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 15, 38, 128)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  activation_37 (Activation)  (None, 15, 38, 128)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  average_pooling2d_3 (Avera  (None, 15, 38, 768)          0         ['mixed3[0][0]']
#  gePooling2D)
#
#  conv2d_30 (Conv2D)          (None, 15, 38, 192)          147456    ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 15, 38, 192)          172032    ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 15, 38, 192)          172032    ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 15, 38, 192)          147456    ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (Ba  (None, 15, 38, 192)          576       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 15, 38, 192)          576       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 15, 38, 192)          576       ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 15, 38, 192)          576       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 15, 38, 192)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  activation_33 (Activation)  (None, 15, 38, 192)          0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  activation_38 (Activation)  (None, 15, 38, 192)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  activation_39 (Activation)  (None, 15, 38, 192)          0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  mixed4 (Concatenate)        (None, 15, 38, 768)          0         ['activation_30[0][0]',
#                                                                      'activation_33[0][0]',
#                                                                      'activation_38[0][0]',
#                                                                      'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 15, 38, 160)          122880    ['mixed4[0][0]']
#
#  batch_normalization_44 (Ba  (None, 15, 38, 160)          480       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  activation_44 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 15, 38, 160)          179200    ['activation_44[0][0]']
#
#  batch_normalization_45 (Ba  (None, 15, 38, 160)          480       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation_45 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 15, 38, 160)          122880    ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 15, 38, 160)          179200    ['activation_45[0][0]']
#
#  batch_normalization_41 (Ba  (None, 15, 38, 160)          480       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 15, 38, 160)          480       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  activation_46 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 15, 38, 160)          179200    ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 15, 38, 160)          179200    ['activation_46[0][0]']
#
#  batch_normalization_42 (Ba  (None, 15, 38, 160)          480       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 15, 38, 160)          480       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_42 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  activation_47 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  average_pooling2d_4 (Avera  (None, 15, 38, 768)          0         ['mixed4[0][0]']
#  gePooling2D)
#
#  conv2d_40 (Conv2D)          (None, 15, 38, 192)          147456    ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 15, 38, 192)          215040    ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 15, 38, 192)          215040    ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 15, 38, 192)          147456    ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (Ba  (None, 15, 38, 192)          576       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 15, 38, 192)          576       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 15, 38, 192)          576       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  batch_normalization_49 (Ba  (None, 15, 38, 192)          576       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 15, 38, 192)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  activation_43 (Activation)  (None, 15, 38, 192)          0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  activation_48 (Activation)  (None, 15, 38, 192)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  activation_49 (Activation)  (None, 15, 38, 192)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  mixed5 (Concatenate)        (None, 15, 38, 768)          0         ['activation_40[0][0]',
#                                                                      'activation_43[0][0]',
#                                                                      'activation_48[0][0]',
#                                                                      'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 15, 38, 160)          122880    ['mixed5[0][0]']
#
#  batch_normalization_54 (Ba  (None, 15, 38, 160)          480       ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_54 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 15, 38, 160)          179200    ['activation_54[0][0]']
#
#  batch_normalization_55 (Ba  (None, 15, 38, 160)          480       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  activation_55 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 15, 38, 160)          122880    ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 15, 38, 160)          179200    ['activation_55[0][0]']
#
#  batch_normalization_51 (Ba  (None, 15, 38, 160)          480       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_56 (Ba  (None, 15, 38, 160)          480       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 15, 38, 160)          0         ['batch_normalization_51[0][0]
# ...
#
#  activation_77 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  activation_81 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  conv2d_78 (Conv2D)          (None, 7, 18, 384)           442368    ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 7, 18, 384)           442368    ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)          (None, 7, 18, 384)           442368    ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)          (None, 7, 18, 384)           442368    ['activation_81[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 7, 18, 1280)          0         ['mixed8[0][0]']
#  gePooling2D)
#
#  conv2d_76 (Conv2D)          (None, 7, 18, 320)           409600    ['mixed8[0][0]']
#
#  batch_normalization_78 (Ba  (None, 7, 18, 384)           1152      ['conv2d_78[0][0]']
#  tchNormalization)
#
#  batch_normalization_79 (Ba  (None, 7, 18, 384)           1152      ['conv2d_79[0][0]']
#  tchNormalization)
#
#  batch_normalization_82 (Ba  (None, 7, 18, 384)           1152      ['conv2d_82[0][0]']
#  tchNormalization)
#
#  batch_normalization_83 (Ba  (None, 7, 18, 384)           1152      ['conv2d_83[0][0]']
#  tchNormalization)
#
#  conv2d_84 (Conv2D)          (None, 7, 18, 192)           245760    ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (Ba  (None, 7, 18, 320)           960       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  activation_78 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  activation_79 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  activation_82 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  activation_83 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  batch_normalization_84 (Ba  (None, 7, 18, 192)           576       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  activation_76 (Activation)  (None, 7, 18, 320)           0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  mixed9_0 (Concatenate)      (None, 7, 18, 768)           0         ['activation_78[0][0]',
#                                                                      'activation_79[0][0]']
#
#  concatenate (Concatenate)   (None, 7, 18, 768)           0         ['activation_82[0][0]',
#                                                                      'activation_83[0][0]']
#
#  activation_84 (Activation)  (None, 7, 18, 192)           0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  mixed9 (Concatenate)        (None, 7, 18, 2048)          0         ['activation_76[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate[0][0]',
#                                                                      'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 7, 18, 448)           917504    ['mixed9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 7, 18, 448)           1344      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_89 (Activation)  (None, 7, 18, 448)           0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  conv2d_86 (Conv2D)          (None, 7, 18, 384)           786432    ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)          (None, 7, 18, 384)           1548288   ['activation_89[0][0]']
#
#  batch_normalization_86 (Ba  (None, 7, 18, 384)           1152      ['conv2d_86[0][0]']
#  tchNormalization)
#
#  batch_normalization_90 (Ba  (None, 7, 18, 384)           1152      ['conv2d_90[0][0]']
#  tchNormalization)
#
#  activation_86 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  activation_90 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  conv2d_87 (Conv2D)          (None, 7, 18, 384)           442368    ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 7, 18, 384)           442368    ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)          (None, 7, 18, 384)           442368    ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 7, 18, 384)           442368    ['activation_90[0][0]']
#
#  average_pooling2d_8 (Avera  (None, 7, 18, 2048)          0         ['mixed9[0][0]']
#  gePooling2D)
#
#  conv2d_85 (Conv2D)          (None, 7, 18, 320)           655360    ['mixed9[0][0]']
#
#  batch_normalization_87 (Ba  (None, 7, 18, 384)           1152      ['conv2d_87[0][0]']
#  tchNormalization)
#
#  batch_normalization_88 (Ba  (None, 7, 18, 384)           1152      ['conv2d_88[0][0]']
#  tchNormalization)
#
#  batch_normalization_91 (Ba  (None, 7, 18, 384)           1152      ['conv2d_91[0][0]']
#  tchNormalization)
#
#  batch_normalization_92 (Ba  (None, 7, 18, 384)           1152      ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 7, 18, 192)           393216    ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (Ba  (None, 7, 18, 320)           960       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  activation_88 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  activation_91 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  activation_92 (Activation)  (None, 7, 18, 384)           0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 7, 18, 192)           576       ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_85 (Activation)  (None, 7, 18, 320)           0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  mixed9_1 (Concatenate)      (None, 7, 18, 768)           0         ['activation_87[0][0]',
#                                                                      'activation_88[0][0]']
#
#  concatenate_1 (Concatenate  (None, 7, 18, 768)           0         ['activation_91[0][0]',
#  )                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)  (None, 7, 18, 192)           0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  mixed10 (Concatenate)       (None, 7, 18, 2048)          0         ['activation_85[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_1[0][0]',
#                                                                      'activation_93[0][0]']
#
#  sequential (Sequential)     (None, 1)                    1651936   ['mixed10[0][0]']
#                                                           1
#
# ==================================================================================================
# Total params: 38322145 (146.19 MB)
# Trainable params: 16519361 (63.02 MB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
print(f'El modelo tardó {(end_time - start_time)/60} minutos en entrenarse.')
# Out:
# El modelo tardó 3.552868171532949 minutos en entrenarse.

# %% [markdown]
# ##### **Precisión y pérdida**

# %%
from matplotlib import pyplot as plt

# Visualizar el rendimiento del modelo durante el entrenamiento
acc_inception = history_inception.history['accuracy']
val_acc_inception = history_inception.history['val_accuracy']
loss_inception = history_inception.history['loss']
val_loss_inception = history_inception.history['val_loss']

epochs_inception = range(len(acc_inception))

# Graficar la precisión
plt.plot(epochs_inception, acc_inception, 'b', label='Training acc')
plt.plot(epochs_inception, val_acc_inception, 'r', label='Validation acc')
plt.title('Training and validation accuracy (Inception-v3)')
plt.legend()
plt.figure()

# Graficar la pérdida
plt.plot(epochs_inception, loss_inception, 'b', label='Training loss')
plt.plot(epochs_inception, val_loss_inception, 'r', label='Validation loss')
plt.title('Training and validation loss (Inception-v3)')
plt.legend()
plt.show()

# %%
import pandas as pd
from IPython.display import HTML

# Valores finales:
resultados = np.array([[history_inception.history['accuracy'][-1],
                        history_inception.history['loss'][-1]],
                       [history_inception.history['val_accuracy'][-1],
                        history_inception.history['val_loss'][-1]]])

df = pd.DataFrame(resultados, index = ['Entrenamiento','Validación'],
                  columns = ['Precisión','Pérdida'])

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Precisión</th>
#       <th>Pérdida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Entrenamiento</th>
#       <td>1.000000</td>
#       <td>0.047610</td>
#     </tr>
#     <tr>
#       <th>Validación</th>
#       <td>0.912752</td>
#       <td>0.219469</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Comprobando la precisión con los datos de prueba**

# %%
# Para liberar memoria y que no se quedé sin espacio en RAM
a = %who_ls
a.remove('model_inception')
a.remove('test_features')
a.remove('test_labels')
a.remove('resultados')
for i in a:
  del globals()[i]

# %%
# Evaluar el modelo con datos de prueba
test_loss_inception, test_acc_inception = model_inception.evaluate(test_features, test_labels)

# Imprimir los resultados de la evaluación con los datos de prueba
print(f'Los resultados de la evaluación con los datos de prueba fueron:\n'
      f'Precisión: {test_acc_inception:.4f}\nPérdida: {test_loss_inception:.4f}')
# Out:
# 4/4 [==============================] - 5s 2s/step - loss: 0.2782 - accuracy: 0.8960
# Los resultados de la evaluación con los datos de prueba fueron:
# Precisión: 0.8960
# Pérdida: 0.2782

# %%
import numpy as np
import pandas as pd
from IPython.display import HTML

# Precisión: Tasa de clasifiación correcta.
# Pérdida  : Cuán cerca está la salida del modelo de las etiquetas reales.
resultados = np.vstack((resultados, [test_acc_inception,test_loss_inception]))
df = pd.DataFrame(resultados, index = ['Entrenamiento','Validación','Test'],
                  columns = ['Precisión','Pérdida'])
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Precisión</th>
#       <th>Pérdida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Entrenamiento</th>
#       <td>1.000000</td>
#       <td>0.047610</td>
#     </tr>
#     <tr>
#       <th>Validación</th>
#       <td>0.912752</td>
#       <td>0.219469</td>
#     </tr>
#     <tr>
#       <th>Test</th>
#       <td>0.896000</td>
#       <td>0.278229</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Guardar modelo**

# %%
import os
os.chdir('..')
# Guardar el modelo Inception-v3
model_inception.save('inceptionv3.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ---
#
# ### **ONE-SHOT LEARNING**
#
# Uno de los principales problemas de los modelos presentados anteriormente es que si la firma no existía dentro de la base de datos no es posible que los modelos identifiquen si la firma es falsa o verdadera y por ende cada vez que queramos reconocer una nueva firma deberíamos re entrenar el modelo por ello este tipo de modelos es importante.
#
# Un modelo one-shot learning se basa en analizar el grado de similiritud entre dos imágenes para definir si estás pertenecen a la misma clase o no por esta razón necesitamos hacer un preprocesamiento de los datos distintos para el one-shot pues necesitamos parejas de imagenes genuinas-genuinas y genuinas-falsas.
#
# Otra ventaja de este tipo de modelos es que necesitan una menor cantidad de datos para su entrenamiento por lo que usaremos sólo los datos de la carpeta train para entrenar nuestro modelo. Veremos más adelante que aún con menos datos el modelo se comporta mucho mejor que los vistos anteriormente.

# %%
import os
import cv2
from tqdm import tqdm
from google.colab import drive
from google.colab.patches import cv2_imshow
drive.mount('/content/drive')
os.chdir('/content/drive/Shareddrives/2023-II/2023-II. Inteligencia Artificial (IA)/Proyecto IA/signature_data')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### **Preprocesamiento de datos para one-shot learning**
#
# Como se dijo anteriormente, necesitamos cargar las imágenes de a pares y si no de a pares por lo menos necesitamos saber cuáles imágenes de firmas genuinas y falsas pertenecen a la misma persona. Hay muchas formas de hacer esto, pero como el modelo puede obtener un gran rendimiento con pocos datos haremos que las firmas de la misma persona tenga la misma cantidad de firmas falsas y firmas genuinas:

# %%
# Nuevamente definimos el mismo alto y ancho
mean_width = 650
mean_height = 268

# %%
os.mkdir('../signature_data_one_shot')
os.chdir('../signature_data_one_shot')
os.mkdir('train_data')
os.mkdir('validation_data')
os.mkdir('test_data')

# %% [markdown]
# Obtenemos la cantidad de firmas falsas y verdaderas que hay en la base de datos para cada persona:

# %%
orig_images = []
forg_images = []
for name in tqdm(sorted(os.listdir('../sign_data/train'))):
    if 'forg' in name.lower():
        forg_images.append(len(os.listdir('../sign_data/train/'+name)))
    else:
        orig_images.append(len(os.listdir('../sign_data/train/'+name)))
# Out:
# 100%|██████████| 128/128 [00:12<00:00,  9.98it/s]

# %% [markdown]
# La cantidad de imágenes que dejaremos será:

# %%
num_orig = min(orig_images)
num_forg = min(forg_images)
print(num_orig, num_forg)
# Out:
# 12 8

# %%
tot_people = len(os.listdir('../sign_data/train'))//2
tot_people
# Out:
# 64

# %%
num_train = 100
num_validation = 14
num_test = 12
for name in tqdm(sorted(os.listdir('../sign_data/train'))):
    if num_train > 0:
        os.mkdir('train_data/'+name)
        if 'forg' in name.lower():
            i = num_forg
        else:
            i = num_orig
        for image_name in sorted(os.listdir('../sign_data/train/'+name)):
            if i <= 0:
                break
            img = cv2.imread('../sign_data/train/'+name+'/'+image_name)
            img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            img_resized = cv2.resize(img_gray, (mean_width, mean_height))
            cv2.imwrite('train_data/'+name+'/'+image_name, img_resized)
            i -= 1
        num_train -= 1
    elif num_validation > 0:
        os.mkdir('validation_data/'+name)
        if 'forg' in name.lower():
            i = num_forg
        else:
            i = num_orig
        for image_name in sorted(os.listdir('../sign_data/train/'+name)):
            if i <= 0:
                break
            img = cv2.imread('../sign_data/train/'+name+'/'+image_name)
            img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            img_resized = cv2.resize(img_gray, (mean_width, mean_height))
            cv2.imwrite('validation_data/'+name+'/'+image_name, img_resized)
            i -= 1
        num_validation -= 1
    elif num_test > 0:
        os.mkdir('test_data/'+name)
        if 'forg' in name.lower():
            i = num_forg
        else:
            i = num_orig
        for image_name in sorted(os.listdir('../sign_data/train/'+name)):
            if i <= 0:
                break
            img = cv2.imread('../sign_data/train/'+name+'/'+image_name)
            img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            img_resized = cv2.resize(img_gray, (mean_width, mean_height))
            cv2.imwrite('test_data/'+name+'/'+image_name, img_resized)
            i -= 1
        num_test -= 1
# Out:
# 100%|██████████| 128/128 [08:00<00:00,  3.75s/it]

# %% [markdown]
# Note que las bases de datos de validación, test y entrenamiento son todas de personas distintas.

# %%
os.chdir('../signature_data_one_shot')
for i in os.listdir():
    personas = os.listdir(i)
    personas = set([persona.split('_')[0] for persona in personas])
    personas = sorted(list(personas))
    print(f'Para la carpeta de {i} están los siguientes números de personas:\n')
    for j in personas:
        print(f'- {j}', end = '\t\t')
    print('\n')
# Out:
# Para la carpeta de train_data están los siguientes números de personas:
#
# - 001		- 002		- 003		- 004		- 006		- 009		- 012		- 013		- 014		- 015		- 016		- 017		- 018		- 019		- 020		- 021		- 022		- 023		- 024		- 025		- 026		- 027		- 028		- 029		- 030		- 031		- 032		- 033		- 034		- 035		- 036		- 037		- 038		- 039		- 040		- 041		- 042		- 043		- 044		- 045		- 046		- 047		- 048		- 049		- 050		- 051		- 052		- 053		- 054		- 055
#
# Para la carpeta de validation_data están los siguientes números de personas:
#
# - 056		- 057		- 058		- 059		- 060		- 061		- 062
#
# Para la carpeta de test_data están los siguientes números de personas:
#
# - 063		- 064		- 065		- 066		- 067		- 068

# %% [markdown]
# #### **Lectura y almacenamiento de los datos**

# %%
import os
import cv2
from tqdm import tqdm
from google.colab import drive
from google.colab.patches import cv2_imshow

drive.mount('/content/drive')
os.chdir('/content/drive/Shareddrives/2023-II/2023-II. Inteligencia Artificial (IA)/Proyecto IA/signature_data_one_shot')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def get_data(dir):
    orig = []
    forg = []
    for name in tqdm(sorted(os.listdir(dir))):
        original = []
        forged = []
        for image_name in sorted(os.listdir(dir+'/'+name)):
            img = dir+'/'+name+'/'+image_name
            if 'forg' in name.lower():
                forged.append(img)
            else:
                original.append(img)

        if 'forg' in name.lower():
            forg.append(forged)
        else:
            orig.append(original)

    return orig, forg

# %%
train_orig, train_forg = get_data('train_data')
validation_orig, validation_forg = get_data('validation_data')
test_orig, test_forg = get_data('test_data')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 1026.04it/s]
# 100%|██████████| 14/14 [00:00<00:00, 1217.81it/s]
# 100%|██████████| 12/12 [00:00<00:00, 1144.94it/s]

# %%
print(len(train_orig))
print(len(train_forg))
print(len(validation_orig))
print(len(validation_forg))
print(len(test_orig))
print(len(test_forg))
# Out:
# 50
# 50
# 7
# 7
# 6
# 6

# %% [markdown]
# #### **Entrenando el modelo**

# %%
import os
import numpy as np
import cv2
from tqdm import tqdm
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import itertools
import random
from sklearn.utils import shuffle
from keras import layers
from keras import models
from keras import backend as K

# %%
def generate_batch(orig_groups, forg_groups, batch_size = 32):
    '''Function to generate a batch of data with batch_size number of data points
    Half of the data points will be Genuine-Genuine pairs and half will be Genuine-Forged pairs'''
    while True:
        orig_pairs = []
        forg_pairs = []
        gen_gen_labels = []
        gen_for_labels = []
        all_pairs = []
        all_labels = []

        # Here we create pairs of Genuine-Genuine image names and Genuine-Forged image names
        # For every person we have 12 genuine signatures, hence we have
        # 12 choose 2 = 66 Genuine-Genuine image pairs for one person.
        # To make Genuine-Forged pairs, we pair every Genuine signature of a person
        # with 8 Forged signatures of the same person.
        # Thus we make 12 * 8 = 96 Genuine-Forged image pairs for one person.
        # In all we have 50 person's data in the training data.
        # Total no. of Genuine-Genuine pairs = 50 * 66 = 3300
        # Total number of Genuine-Forged pairs = 50 * 96 = 4800
        # Total no. of data points = 3300 + 4800 = 8100
        for orig, forg in zip(orig_groups, forg_groups):
            orig_pairs.extend(list(itertools.combinations(orig, 2)))
            for i in range(len(orig)):
                forg_pairs.extend(list(itertools.product(orig[i:i+1], forg)))

        # Label for Genuine-Genuine pairs is 1
        # Label for Genuine-Forged pairs is 0
        gen_gen_labels = [1]*len(orig_pairs)
        gen_for_labels = [0]*len(forg_pairs)

        # Concatenate all the pairs together along with their labels and shuffle them
        all_pairs = orig_pairs + forg_pairs
        all_labels = gen_gen_labels + gen_for_labels
        del orig_pairs, forg_pairs, gen_gen_labels, gen_for_labels
        all_pairs, all_labels = shuffle(all_pairs, all_labels)

        k = 0
        pairs=[np.zeros((batch_size, 268, 650, 1)) for i in range(2)]
        targets=np.zeros((batch_size,))
        for ix, pair in enumerate(all_pairs):
            img1 = cv2.imread(pair[0], cv2.IMREAD_GRAYSCALE)
            img2 = cv2.imread(pair[1], cv2.IMREAD_GRAYSCALE)
            img1 = np.array(img1, dtype = np.float64)
            img2 = np.array(img2, dtype = np.float64)
            img1 /= 255
            img2 /= 255
            img1 = img1[..., np.newaxis]
            img2 = img2[..., np.newaxis]
            pairs[0][k, :, :, :] = img1
            pairs[1][k, :, :, :] = img2
            targets[k] = all_labels[ix]
            k += 1
            if k == batch_size:
                targets = targets.astype(int)
                yield pairs, targets
                k = 0
                pairs=[np.zeros((batch_size, 268, 650, 1)) for i in range(2)]
                targets=np.zeros((batch_size,))

# %%
# Obtener el primer lote del generador
primer_lote = next(generate_batch(test_orig, test_forg,1))

# %%
cv2_imshow(primer_lote[0][0][0] * 255)
cv2_imshow(primer_lote[0][1][0] * 255)

len(primer_lote[1])
# Out:
# <PIL.Image.Image image mode=RGB size=650x268>
# <PIL.Image.Image image mode=RGB size=650x268>
# 1

# %%
def euclidean_distance(vects):
    '''Compute Euclidean Distance between two vectors'''
    x, y = vects
    return K.sqrt(K.sum(K.square(x - y), axis=1, keepdims=True))

# %%
def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
def create_base_network_signet(input_shape):
    '''Base Siamese Network'''

    model = models.Sequential()
    model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape,padding='same'))
    model.add(layers.MaxPooling2D((2, 2),padding='same'))
    model.add(layers.Conv2D(64, (3, 3), activation='relu',padding='same'))
    model.add(layers.MaxPooling2D((2, 2),padding='same'))
    model.add(layers.Conv2D(64, (3, 3), activation='relu',padding='same'))
    model.add(layers.MaxPooling2D((2, 2),padding='same'))
    model.add(layers.Flatten())
    model.add(layers.Dense(1024, activation='relu'))
    model.add(layers.Dense(128, activation='relu'))

    return model

# %%
input_shape=(268, 650, 1)
base_network = create_base_network_signet(input_shape)

input_a = layers.Input(shape=(input_shape))
input_b = layers.Input(shape=(input_shape))

processed_a = base_network(input_a)
processed_b = base_network(input_b)

distance = layers.Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([processed_a, processed_b])
prediction = layers.Dense(1,activation='sigmoid')(distance)

model = models.Model(inputs=[input_a, input_b], outputs=prediction)

# %%
model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])

# %%
num_train_samples = 66*50 + 96*50
num_val_samples = 66*7 + 96*7
num_train_samples, num_val_samples
# Out:
# (8100, 1134)

# %%
import time

strat_time = time.time()
batch_size=64
history = model.fit(generate_batch(train_orig, train_forg, batch_size),
                   steps_per_epoch = num_train_samples//batch_size,
                   epochs = 6,
                   validation_data = generate_batch(validation_orig, validation_forg, batch_size),
                   validation_steps = num_val_samples//batch_size)
end_time = time.time()
# Out:
# Epoch 1/6
# 126/126 [==============================] - 139s 992ms/step - loss: 0.3365 - accuracy: 0.8228 - val_loss: 0.2866 - val_accuracy: 1.0000
# Epoch 2/6
# 126/126 [==============================] - 121s 961ms/step - loss: 0.2613 - accuracy: 0.9882 - val_loss: 0.2532 - val_accuracy: 0.9982
# Epoch 3/6
# 126/126 [==============================] - 123s 982ms/step - loss: 0.2332 - accuracy: 0.9929 - val_loss: 0.2331 - val_accuracy: 1.0000
# Epoch 4/6
# 126/126 [==============================] - 138s 1s/step - loss: 0.2102 - accuracy: 0.9957 - val_loss: 0.1998 - val_accuracy: 1.0000
# Epoch 5/6
# 126/126 [==============================] - 111s 886ms/step - loss: 0.1898 - accuracy: 0.9955 - val_loss: 0.1930 - val_accuracy: 1.0000
# Epoch 6/6
# 126/126 [==============================] - 133s 1s/step - loss: 0.1717 - accuracy: 0.9970 - val_loss: 0.1918 - val_accuracy: 1.0000

# %% [markdown]
# #### **Resultados**

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 268, 650, 1)]        0         []
#
#  input_2 (InputLayer)        [(None, 268, 650, 1)]        0         []
#
#  sequential (Sequential)     (None, 128)                  1829023   ['input_1[0][0]',
#                                                           36         'input_2[0][0]']
#
#  lambda (Lambda)             (None, 1)                    0         ['sequential[0][0]',
#                                                                      'sequential[1][0]']
#
#  dense_2 (Dense)             (None, 1)                    2         ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 182902338 (697.72 MB)
# Trainable params: 182902338 (697.72 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
print(f'El modelo tardo {(end_time - strat_time)/60} minutos en entrenarse.')
# Out:
# El modelo tardo 12.779057621955872 minutos en entrenarse.

# %% [markdown]
# ##### Precisión y pérdida

# %%
from matplotlib import pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import pandas as pd
from IPython.display import HTML

# Valores finales:
resultados = np.array([[history.history['accuracy'][-1],
                        history.history['loss'][-1]],
                       [history.history['val_accuracy'][-1],
                        history.history['val_loss'][-1]]])

df = pd.DataFrame(resultados, index = ['Entrenamiento','Validación'],
                  columns = ['Precisión','Pérdida'])

display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Precisión</th>
#       <th>Pérdida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Entrenamiento</th>
#       <td>0.997024</td>
#       <td>0.171696</td>
#     </tr>
#     <tr>
#       <th>Validación</th>
#       <td>1.000000</td>
#       <td>0.191797</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Comprobando la precisión con los datos de prueba**

# %%
# Para liberar RAM
a = %who_ls
a.remove('model')
a.remove('test_forg')
a.remove('test_orig')
a.remove('resultados')
a.remove('generate_batch')
a.remove('itertools')
a.remove('random')
a.remove('shuffle')
a.remove('np')
a.remove('cv2')
for i in a:
  del globals()[i]

# %%
num_test_samples = 66*7 + 96*7
test_loss, test_acc = model.evaluate(generate_batch(test_orig, test_forg, 1), steps=num_test_samples)
# Out:
# 1134/1134 [==============================] - 19s 16ms/step - loss: 0.1704 - accuracy: 1.0000

# %%
print(f'Los resultados de la evaluación con los datos de prueba fueron:\n'
      f'- Precisión: {test_acc:.4f}\n- Pérdida: {test_loss:.4f}')
# Out:
# Los resultados de la evaluación con los datos de prueba fueron:
# - Precisión: 1.0000
# - Pérdida: 0.1704

# %%
import numpy as np
import pandas as pd
from IPython.display import HTML

# Precisión: Tasa de clasifiación correcta.
# Pérdida  : Cuán cerca está la salida del modelo de las etiquetas reales.
resultados = np.vstack((resultados, [test_acc,test_loss]))
df = pd.DataFrame(resultados, index = ['Entrenamiento','Validación','Test'],
                  columns = ['Precisión','Pérdida'])
display(HTML(df.to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Precisión</th>
#       <th>Pérdida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Entrenamiento</th>
#       <td>0.997024</td>
#       <td>0.171696</td>
#     </tr>
#     <tr>
#       <th>Validación</th>
#       <td>1.000000</td>
#       <td>0.191797</td>
#     </tr>
#     <tr>
#       <th>Test</th>
#       <td>1.000000</td>
#       <td>0.170368</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Guardando el modelo**

# %%
import os
os.chdir('..')
model.save('oneshot.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# #### **Matriz de confusión**

# %%
import os
import numpy as np
import cv2
from tqdm import tqdm
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
import itertools
import random
from sklearn.utils import shuffle
from keras import layers
from keras import models
from keras import backend as K

os.chdir('/content/drive/Shareddrives/2023-II/2023-II. Inteligencia Artificial (IA)/Proyecto IA/signature_data_one_shot')
model = models.load_model('../oneshot.h5')

# %%
num_test_samples = 66*7 + 96*7
# num_test_samples = 10
true_labels = []
predicted_labels = []
for i in tqdm(range(1,num_test_samples)):
    a = next(generate_batch(test_orig, test_forg, 1))
    true_labels.append(a[1][0])
    if model.predict(a[0], verbose = 0) < 0.5:
      predicted_labels.append(0)
    else:
      predicted_labels.append(1)
# Out:
# 100%|██████████| 1133/1133 [01:45<00:00, 10.70it/s]

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import numpy as np

confussion = tf.math.confusion_matrix(
    true_labels,
    predicted_labels
)

# %%
from sklearn.metrics import confusion_matrix, classification_report
print("Informe de Clasificación:")
print(classification_report(true_labels, predicted_labels))
# Out:
# Informe de Clasificación:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       644
#            1       1.00      1.00      1.00       489
#
#     accuracy                           1.00      1133
#    macro avg       1.00      1.00      1.00      1133
# weighted avg       1.00      1.00      1.00      1133

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(a[0][1][0] * 255)
# Out:
# <PIL.Image.Image image mode=RGB size=650x268>

# %%
cv2_imshow(a[0][1][0] * 255)
# Out:
# <PIL.Image.Image image mode=RGB size=650x268>

# %%
a[1][0], predicted_labels[-1]
# Out:
# (1, 1)

# %%
true_labels == predicted_labels
# Out:
# True
